# %%
import math
import random
import numpy as np

# objective function to be optimized
def objective_function(x, y):
    return (1-x)**2*math.exp(-x**2-(y+1)**2) - (x-x**3-y**3)*math.exp(-x**2-y**2)

# genetic algorithm
def genetic_algorithm(objective_function, n_iterations, n_population, n_parents, mutation_rate, crossover_rate, search_space):

    population = np.random.uniform(low=search_space[0], high=search_space[1], size=(n_population, 2))

    for i in range(n_iterations):
        fitness = np.array([objective_function(x, y) for x, y in population])
        parents = population[np.argsort(fitness)[:n_parents]]

        offspring = np.empty((n_population, 2))
        for j in range(n_population):
            parent1 = random.choice(parents)
            parent2 = random.choice(parents)

            if random.random() < crossover_rate:
                child = parent1 + mutation_rate * (parent2 - parent1)
            else:
                child = parent1

            for k in range(2):
                if random.random() < mutation_rate:
                    child[k] += np.random.normal(0, 1) * (search_space[1] - search_space[0]) / 10.0  # Gaussian mutation

            offspring[j] = child

            population = offspring

        best_solution_idx = np.argmin(fitness)
        best_solution = population[best_solution_idx]
        best_fitness = fitness[best_solution_idx]
        print("Generation {}: Best solution found: x = {:.4f}, y = {:.4f}, f(x,y) = {:.4f}".format(i+1, best_solution[0], best_solution[1], best_fitness))

    fitness = np.array([objective_function(x, y) for x, y in population])
    best_solution_idx = np.argmin(fitness)
    best_solution = population[best_solution_idx]

    return best_solution

search_space = [-2.0, 2.0]  # parameters
n_iterations = 200  # generations
n_population = 8  # population
n_parents = 10  # parents for mating
mutation_rate = 0.01  # mutation rate
crossover_rate = 0.7  # crossover rate
best_solution = genetic_algorithm(objective_function, n_iterations, n_population, n_parents, mutation_rate, crossover_rate, search_space)

print("Best solution found: x = {:.4f}, y = {:.4f}, f(x,y) = {:.4f}".format(best_solution[0], best_solution[1], objective_function(*best_solution)))
# Out:
# Generation 1: Best solution found: x = -0.3032, y = -1.9344, f(x,y) = -0.0762
# Generation 2: Best solution found: x = -0.2858, y = -1.9126, f(x,y) = 0.0172
# Generation 3: Best solution found: x = -0.2858, y = -1.9126, f(x,y) = 0.0313
# Generation 4: Best solution found: x = -1.0706, y = 0.6315, f(x,y) = 0.0503
# Generation 5: Best solution found: x = -1.1010, y = 0.6471, f(x,y) = 0.0944
# Generation 6: Best solution found: x = 1.4336, y = 0.2447, f(x,y) = 0.0944
# Generation 7: Best solution found: x = -1.0930, y = 0.6217, f(x,y) = 0.1013
# Generation 8: Best solution found: x = -1.0677, y = 0.6180, f(x,y) = 0.1013
# Generation 9: Best solution found: x = -1.0677, y = 0.6180, f(x,y) = 0.1013
# Generation 10: Best solution found: x = -1.0514, y = 0.6385, f(x,y) = 0.1013
# Generation 11: Best solution found: x = -1.0514, y = 0.6385, f(x,y) = 0.1185
# Generation 12: Best solution found: x = 1.3667, y = 0.2318, f(x,y) = 0.1185
# Generation 13: Best solution found: x = -1.0678, y = 0.6182, f(x,y) = 0.1185
# Generation 14: Best solution found: x = 1.2719, y = 0.2471, f(x,y) = 0.1186
# Generation 15: Best solution found: x = 1.2719, y = 0.2471, f(x,y) = 0.1186
# Generation 16: Best solution found: x = 1.3194, y = 0.2396, f(x,y) = 0.1431
# Generation 54: Best solution found: x = 1.3254, y = 0.2409, f(x,y) = 0.1695
# Generation 55: Best solution found: x = 1.3254, y = 0.2409, f(x,y) = 0.1695
# Generation 56: Best solution found: x = 1.3254, y = 0.2409, f(x,y) = 0.1507
# Generation 57: Best solution found: x = 1.3253, y = 0.5462, f(x,y) = 0.1507
# Generation 58: Best solution found: x = 0.4343, y = 0.2439, f(x,y) = 0.1508
# Generation 59: Best solution found: x = 1.3254, y = 0.2439, f(x,y) = -0.2072
# Generation 60: Best solution found: x = 1.3253, y = 0.5433, f(x,y) = 0.1510
# Generation 61: Best solution found: x = 1.2162, y = 0.5431, f(x,y) = 0.1512
# Generation 62: Best solution found: x = 1.3254, y = 0.2470, f(x,y) = 0.1270
# Generation 63: Best solution found: x = 1.3253, y = 0.5373, f(x,y) = 0.1513
# Generation 64: Best solution found: x = 1.3253, y = 0.5315, f(x,y) = 0.1513
# Generation 65: Best solution found: x = 1.3253, y = 0.5344, f(x,y) = 0.1515
# Generation 66: Best solution found: x = 1.3253, y = 0.5374, f(x,y) = 0.1515
# Generation 67: Best solution found: x = 1.3253, y = 0.5344, f(x,y) = 0.1515
# Generation 68: Best solution found: x = 1.3253, y = 0.5344, f(x,y) = 0.1515
# Generation 69: Best solution found: x = 1.3253, y = 0.5344, f(x,y) = 0.1515
# Generation 70: Best solution found: x = 1.3253, y = 0.5374, f(x,y) = 0.1515
# Generation 71: Best solution found: x = 1.3253, y = 0.5289, f(x,y) = 0.1515
# Generation 72: Best solution found: x = 1.3253, y = 0.5371, f(x,y) = 0.1515
# Generation 73: Best solution found: x = 1.3253, y = 0.5289, f(x,y) = 0.1515
# Generation 74: Best solution found: x = 1.3253, y = 0.5289, f(x,y) = 0.1515
# Generation 75: Best solution found: x = 1.3253, y = 0.5289, f(x,y) = 0.1515
# Generation 76: Best solution found: x = 1.3253, y = 0.5369, f(x,y) = 0.1515
# Generation 77: Best solution found: x = 1.3253, y = 0.5368, f(x,y) = 0.1515
# Generation 78: Best solution found: x = 1.3253, y = 0.5369, f(x,y) = 0.1515
# Generation 79: Best solution found: x = 1.3253, y = 0.5369, f(x,y) = 0.1515
# Generation 80: Best solution found: x = 1.3253, y = 0.5290, f(x,y) = 0.1515
# Generation 81: Best solution found: x = 1.3253, y = 0.5290, f(x,y) = 0.0489
# Generation 82: Best solution found: x = 1.3253, y = 0.5291, f(x,y) = 0.0503
# Generation 83: Best solution found: x = 1.3223, y = 0.5369, f(x,y) = 0.0503
# Generation 84: Best solution found: x = 1.3223, y = 0.5291, f(x,y) = 0.0517
# Generation 85: Best solution found: x = 1.3223, y = 0.5291, f(x,y) = 0.1509
# Generation 86: Best solution found: x = 1.3223, y = 0.5291, f(x,y) = 0.1509
# Generation 87: Best solution found: x = 1.3194, y = 0.5291, f(x,y) = 0.1509
# Generation 88: Best solution found: x = 1.3223, y = 0.5291, f(x,y) = 0.1509
# Generation 89: Best solution found: x = 1.3223, y = 0.5291, f(x,y) = 0.1509
# Generation 90: Best solution found: x = 1.3222, y = 0.5291, f(x,y) = 0.1509
# Generation 128: Best solution found: x = 1.3239, y = 0.5291, f(x,y) = 0.1446
# Generation 129: Best solution found: x = 1.3276, y = 0.5291, f(x,y) = 0.1452
# Generation 130: Best solution found: x = 1.3239, y = 0.5291, f(x,y) = 0.1457
# Generation 131: Best solution found: x = 1.3239, y = 0.5291, f(x,y) = 0.1463
# Generation 132: Best solution found: x = 1.3239, y = 0.5291, f(x,y) = 0.1463
# Generation 133: Best solution found: x = 1.3239, y = 0.5970, f(x,y) = 0.1468
# Generation 134: Best solution found: x = 1.3239, y = 0.5828, f(x,y) = 0.1468
# Generation 135: Best solution found: x = 1.3275, y = 0.5823, f(x,y) = 0.1468
# Generation 136: Best solution found: x = 1.3275, y = 0.5823, f(x,y) = 0.1473
# Generation 137: Best solution found: x = 1.3344, y = 0.5813, f(x,y) = 0.1473
# Generation 138: Best solution found: x = 1.6770, y = 0.5297, f(x,y) = 0.1473
# Generation 139: Best solution found: x = 1.6736, y = 0.5302, f(x,y) = 0.1473
# Generation 140: Best solution found: x = 1.3412, y = 0.5802, f(x,y) = 0.1473
# Generation 141: Best solution found: x = 1.3412, y = 0.5802, f(x,y) = 0.1473
# Generation 142: Best solution found: x = 1.3445, y = 0.5797, f(x,y) = 0.1477
# Generation 143: Best solution found: x = 1.6736, y = 0.5302, f(x,y) = 0.1477
# Generation 144: Best solution found: x = 1.6737, y = 0.5302, f(x,y) = 0.1477
# Generation 145: Best solution found: x = 1.6703, y = 0.5307, f(x,y) = 0.1477
# Generation 146: Best solution found: x = 1.6736, y = 0.5302, f(x,y) = 0.1477
# Generation 147: Best solution found: x = 1.6736, y = 0.5302, f(x,y) = 0.1287
# Generation 148: Best solution found: x = 1.6736, y = 0.5302, f(x,y) = 0.1477
# Generation 149: Best solution found: x = 1.6704, y = 0.5307, f(x,y) = 0.1477
# Generation 150: Best solution found: x = 1.6736, y = 0.5302, f(x,y) = 0.1477
# Generation 151: Best solution found: x = 1.3543, y = 0.5783, f(x,y) = 0.1477
# Generation 152: Best solution found: x = 1.3543, y = 0.5783, f(x,y) = 0.1481
# Generation 153: Best solution found: x = 1.3574, y = 0.5778, f(x,y) = 0.1481
# Generation 154: Best solution found: x = 1.3540, y = 0.5778, f(x,y) = 0.1529
# Generation 155: Best solution found: x = 1.3540, y = 0.5778, f(x,y) = 0.1529
# Generation 156: Best solution found: x = 1.3540, y = 0.5778, f(x,y) = 0.1529
# Generation 157: Best solution found: x = 1.3540, y = 0.5320, f(x,y) = 0.1529
# Generation 158: Best solution found: x = 1.3540, y = 0.5778, f(x,y) = 0.1505
# Generation 159: Best solution found: x = 1.3540, y = 0.5773, f(x,y) = 0.1505
# Generation 160: Best solution found: x = 1.3540, y = 0.2153, f(x,y) = 0.1529
# Generation 161: Best solution found: x = 1.3540, y = 0.2153, f(x,y) = 0.1529
# Generation 162: Best solution found: x = 1.3540, y = 0.5742, f(x,y) = 0.1529
# Generation 163: Best solution found: x = 1.3540, y = 0.2185, f(x,y) = 0.1532
# Generation 164: Best solution found: x = 1.3540, y = 0.5706, f(x,y) = 0.1532
# Generation 165: Best solution found: x = 1.3540, y = 0.5706, f(x,y) = 0.1532
# Generation 166: Best solution found: x = 1.3540, y = 0.2184, f(x,y) = 0.1532
# Generation 167: Best solution found: x = 1.3540, y = 0.5741, f(x,y) = 0.1532
# Generation 168: Best solution found: x = 1.3540, y = 0.2219, f(x,y) = 0.1532
# Generation 169: Best solution found: x = 1.3540, y = 0.2219, f(x,y) = 0.1532
# Generation 170: Best solution found: x = 1.3540, y = 0.2220, f(x,y) = 0.1539
# Generation 171: Best solution found: x = 1.3540, y = 0.2255, f(x,y) = 0.1541
# Generation 172: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 173: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 174: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 175: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 176: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 177: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 178: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1727
# Generation 179: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 180: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 181: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 182: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 183: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 184: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 185: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 186: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 187: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 188: Best solution found: x = 1.3540, y = 0.2254, f(x,y) = 0.1777
# Generation 189: Best solution found: x = 1.5491, y = 0.2254, f(x,y) = 0.1777
# Generation 190: Best solution found: x = 1.5472, y = 0.2254, f(x,y) = 0.1448
# Generation 191: Best solution found: x = 1.3591, y = 0.2258, f(x,y) = 0.1779
# Generation 192: Best solution found: x = 1.3572, y = 0.2254, f(x,y) = 0.1779
# Generation 193: Best solution found: x = 1.3591, y = 0.2258, f(x,y) = 0.1784
# Generation 194: Best solution found: x = 1.5465, y = 0.2258, f(x,y) = 0.1784
# Generation 195: Best solution found: x = 1.5465, y = 0.2258, f(x,y) = 0.1784
# Generation 196: Best solution found: x = 1.3591, y = 0.2254, f(x,y) = 0.1784
# Generation 197: Best solution found: x = 1.3572, y = 0.2254, f(x,y) = 0.1784
# Generation 198: Best solution found: x = 1.5446, y = 0.2258, f(x,y) = 0.1784
# Generation 199: Best solution found: x = 1.3628, y = 0.2254, f(x,y) = 0.1784
# Generation 200: Best solution found: x = 1.5410, y = 0.2258, f(x,y) = 0.1788
# Best solution found: x = 1.3591, y = 0.2254, f(x,y) = 0.1788
